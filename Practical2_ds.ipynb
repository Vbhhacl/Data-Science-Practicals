# %% [markdown]
# <a href="https://colab.research.google.com/github/Vbhhacl/Data-Science-Practicals/blob/main/Practical2_ds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
from scipy.stats import skew

# %%
df=pd.read_csv("StudentsPerformance.csv")

# %%
df.head()
# Out:
#    Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0        80.0           90.0           70.0               77            2018
# 1        70.0           77.0           76.0               85            2018
# 2        62.0           88.0           68.0               92            2019
# 3        94.0           84.0           71.0               78            2019
# 4        78.0           81.0           62.0              100            2020
#
#    Placement_Offer_Count
# 0                      2
# 1                      3
# 2                      3
# 3                      2
# 4                      3

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         80.0           90.0           70.0               77            2018
# 1         70.0           77.0           76.0               85            2018
# 2         62.0           88.0           68.0               92            2019
# 3         94.0           84.0           71.0               78            2019
# 4         78.0           81.0           62.0              100            2020
# 5         77.0          200.0           73.0               82            2020
# 6         77.0           75.0           65.0              100            2020
# 7         62.0           80.0           63.0               97            2019
# 8         79.0           88.0           65.0               82            2018
# 9         63.0           94.0           73.0               79            2021
# 10        66.0           79.0           77.0               80            2019
# ...

# %%
df.shape
# Out:
# (30, 6)

# %%
df.isnull()
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# 5        False          False          False            False           False
# 6        False          False          False            False           False
# 7        False          False          False            False           False
# 8        False          False          False            False           False
# 9        False          False          False            False           False
# 10       False          False          False            False           False
# ...

# %%
df.isnull().sum()
# Out:
# Math_score               1
# Reading_score            1
# Writing_score            1
# Placement_score          0
# Club_Join_Date           0
# Placement_Offer_Count    0
# dtype: int64

# %%
series=pd.isnull(df["Math_score"])
df[series]
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 24         NaN           81.0           66.0               81            2019
#
#     Placement_Offer_Count
# 24                      2

# %%
df.notnull()
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         True           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True           True             True            True
# 5         True           True           True             True            True
# 6         True           True           True             True            True
# 7         True           True           True             True            True
# 8         True           True           True             True            True
# 9         True           True           True             True            True
# 10        True           True           True             True            True
# ...

# %%
df.describe()
# Out:
#        Math_score  Reading_score  Writing_score  Placement_score  \
# count   29.000000      29.000000      29.000000        30.000000
# mean    75.103448      88.068966      69.620690        85.633333
# std     21.699810      22.238851       5.734693         8.833648
# min     61.000000      75.000000      61.000000        75.000000
# 25%     65.000000      80.000000      64.000000        77.250000
# 50%     70.000000      83.000000      70.000000        82.000000
# 75%     78.000000      90.000000      74.000000        93.000000
# max    180.000000     200.000000      79.000000       100.000000
#
#        Club_Join_Date  Placement_Offer_Count
# count       30.000000              30.000000
# mean      2019.466667               2.433333
# std          0.899553               0.568321
# min       2018.000000               1.000000
# 25%       2019.000000               2.000000
# 50%       2020.000000               2.000000
# 75%       2020.000000               3.000000
# ...

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         80.0           90.0           70.0               77            2018
# 1         70.0           77.0           76.0               85            2018
# 2         62.0           88.0           68.0               92            2019
# 3         94.0           84.0           71.0               78            2019
# 4         78.0           81.0           62.0              100            2020
# 5         77.0          200.0           73.0               82            2020
# 6         77.0           75.0           65.0              100            2020
# 7         62.0           80.0           63.0               97            2019
# 8         79.0           88.0           65.0               82            2018
# 9         63.0           94.0           73.0               79            2021
# 10        66.0           79.0           77.0               80            2019
# ...

# %%
df1=df

# %%
df1.fillna(0)
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         80.0           90.0           70.0               77            2018
# 1         70.0           77.0           76.0               85            2018
# 2         62.0           88.0           68.0               92            2019
# 3         94.0           84.0           71.0               78            2019
# 4         78.0           81.0           62.0              100            2020
# 5         77.0          200.0           73.0               82            2020
# 6         77.0           75.0           65.0              100            2020
# 7         62.0           80.0           63.0               97            2019
# 8         79.0           88.0           65.0               82            2018
# 9         63.0           94.0           73.0               79            2021
# 10        66.0           79.0           77.0               80            2019
# ...

# %%
df2=df

# %%
df2["Math_score"]=df2["Math_score"].fillna(df2["Math_score"].mean())

# %%
df2
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    80.000000           90.0           70.0               77            2018
# 1    70.000000           77.0           76.0               85            2018
# 2    62.000000           88.0           68.0               92            2019
# 3    94.000000           84.0           71.0               78            2019
# 4    78.000000           81.0           62.0              100            2020
# 5    77.000000          200.0           73.0               82            2020
# 6    77.000000           75.0           65.0              100            2020
# 7    62.000000           80.0           63.0               97            2019
# 8    79.000000           88.0           65.0               82            2018
# 9    63.000000           94.0           73.0               79            2021
# 10   66.000000           79.0           77.0               80            2019
# ...

# %%
col=["Math_score","Reading_score","Writing_score","Placement_score"]

# %%
df.boxplot(col)
# Out:
# <Axes: >

# %%
new_df=pd.read_csv("StudentsPerformance.csv")
new_df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         80.0           90.0           70.0               77            2018
# 1         70.0           77.0           76.0               85            2018
# 2         62.0           88.0           68.0               92            2019
# 3         94.0           84.0           71.0               78            2019
# 4         78.0           81.0           62.0              100            2020
# 5         77.0          200.0           73.0               82            2020
# 6         77.0           75.0           65.0              100            2020
# 7         62.0           80.0           63.0               97            2019
# 8         79.0           88.0           65.0               82            2018
# 9         63.0           94.0           73.0               79            2021
# 10        66.0           79.0           77.0               80            2019
# ...

# %%
print(np.where(new_df["Math_score"]>90))
# Out:
# (array([ 3, 17]),)

# %%
mean1=np.mean(df["Math_score"])
mean1
# Out:
# np.float64(75.10344827586208)

# %%
z=stats.zscore(df['Math_score'])

# %%
z
# Out:
# array([ 2.33569439e-01, -2.43438570e-01, -6.25044978e-01,  9.01380653e-01,
#         1.38167837e-01,  9.04670363e-02,  9.04670363e-02, -6.25044978e-01,
#         1.85868638e-01, -5.77344177e-01, -4.34241774e-01, -2.91139371e-01,
#         2.33569439e-01, -4.34241774e-01, -5.29643376e-01,  1.38167837e-01,
#        -6.72745779e-01,  5.00364954e+00,  2.33569439e-01, -2.43438570e-01,
#        -2.91139371e-01, -1.95737769e-01, -1.95737769e-01, -6.72745779e-01,
#        -6.77869152e-16,  4.27662353e-02, -3.38840172e-01, -6.72745779e-01,
#         2.33569439e-01, -4.81942575e-01])

# %%
threshold= 3

# %%
sample_outliers = np.where(z>threshold)
sample_outliers
# Out:
# (array([17]),)

# %%
Q1=df.Math_score.quantile(0.25)
Q1
# Out:
# np.float64(65.25)

# %%
Q3=df.Math_score.quantile(0.75)

# %%
Q1
# Out:
# np.float64(65.25)

# %%
Q3
# Out:
# np.float64(78.0)

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# np.float64(12.75)

# %%
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (np.float64(46.125), np.float64(97.125))

# %%
df[(df.Math_score<lower_limit)|(df.Math_score>upper_limit)]
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 17       180.0           82.0           76.0               95            2019
#
#     Placement_Offer_Count
# 17                      3

# %%
sample_outliers1=df["Math_score"][(df["Math_score"]>upper_limit)|(df["Math_score"]<lower_limit)]

# %%
sample_outliers1
# Out:
# 17    180.0
# Name: Math_score, dtype: float64

# %%
index_outliers=np.where((df.Math_score<lower_limit)|(df.Math_score>upper_limit))
index_outliers
# Out:
# (array([17]),)

# %%
redefined_df=df2
redefined_df['Math_score']=np.where((redefined_df['Math_score'] >upper_limit),mean1,redefined_df['Math_score'])

# %%
redefined_df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    80.000000           90.0           70.0               77            2018
# 1    70.000000           77.0           76.0               85            2018
# 2    62.000000           88.0           68.0               92            2019
# 3    94.000000           84.0           71.0               78            2019
# 4    78.000000           81.0           62.0              100            2020
# 5    77.000000          200.0           73.0               82            2020
# 6    77.000000           75.0           65.0              100            2020
# 7    62.000000           80.0           63.0               97            2019
# 8    79.000000           88.0           65.0               82            2018
# 9    63.000000           94.0           73.0               79            2021
# 10   66.000000           79.0           77.0               80            2019
# ...

# %%
col1=['Math_score']

# %%
redefined_df.boxplot(col1)
# Out:
# <Axes: >

# %%
redefined_df.plot(kind="bar")
# Out:
# <Axes: >

# %%
df_min_max_scaled=redefined_df.copy()
for column in df_min_max_scaled.columns:
    df_min_max_scaled[column]= (df_min_max_scaled[column]-df_min_max_scaled[column].min())/(df_min_max_scaled[column].max()-df_min_max_scaled[column].min())
df_min_max_scaled
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0     0.575758          0.120       0.500000             0.08        0.000000
# 1     0.272727          0.016       0.833333             0.40        0.000000
# 2     0.030303          0.104       0.388889             0.68        0.333333
# 3     1.000000          0.072       0.555556             0.12        0.333333
# 4     0.515152          0.048       0.055556             1.00        0.666667
# 5     0.484848          1.000       0.666667             0.28        0.666667
# 6     0.484848          0.000       0.222222             1.00        0.666667
# 7     0.030303          0.040       0.111111             0.88        0.333333
# 8     0.545455          0.104       0.222222             0.28        0.000000
# 9     0.060606          0.152       0.666667             0.16        1.000000
# 10    0.151515          0.032       0.888889             0.20        0.333333
# ...

# %%
df_min_max_scaled.plot(kind="bar")
# Out:
# <Axes: >

# %%
df_min_max_scaled.skew()
# Out:
# Math_score               0.585311
# Reading_score            4.851150
# Writing_score           -0.021881
# Placement_score          0.356732
# Club_Join_Date          -0.198060
# Placement_Offer_Count   -0.325614
# dtype: float64

# %%
df_min_max_scaled.kurtosis()
# Out:
# Math_score                0.432856
# Reading_score            25.077044
# Writing_score            -1.464533
# Placement_score          -1.450360
# Club_Join_Date           -0.668386
# Placement_Offer_Count    -0.819012
# dtype: float64

# %%
df_min_max_scaled=redefined_df.copy()
for column in df_min_max_scaled.columns:
    df_min_max_scaled[column]= (df_min_max_scaled[column]-df_min_max_scaled[column].min())/(df_min_max_scaled[column].max()-df_min_max_scaled[column].min())
df_min_max_scaled
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0     0.575758          0.120       0.500000             0.08        0.000000
# 1     0.272727          0.016       0.833333             0.40        0.000000
# 2     0.030303          0.104       0.388889             0.68        0.333333
# 3     1.000000          0.072       0.555556             0.12        0.333333
# 4     0.515152          0.048       0.055556             1.00        0.666667
# 5     0.484848          1.000       0.666667             0.28        0.666667
# 6     0.484848          0.000       0.222222             1.00        0.666667
# 7     0.030303          0.040       0.111111             0.88        0.333333
# 8     0.545455          0.104       0.222222             0.28        0.000000
# 9     0.060606          0.152       0.666667             0.16        1.000000
# 10    0.151515          0.032       0.888889             0.20        0.333333
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(redefined_df['Math_score'], bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, data=None)
# Out:
# (array([7., 3., 5., 2., 5., 7., 0., 0., 0., 1.]),
#  array([61. , 64.3, 67.6, 70.9, 74.2, 77.5, 80.8, 84.1, 87.4, 90.7, 94. ]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
plt.distplot(redefined_df['Writing_score'], bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, data=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3314851064.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.distplot(redefined_df['Writing_score'], bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, data=None)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'distplot'

# %%
import matplotlib.pyplot as plt
plt.distplot(redefined_df['Reading_score'], bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, data=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3004321737.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.distplot(redefined_df['Reading_score'], bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, data=None)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'distplot'

# %%
skew_value3 = skew(df['Placement_score'])
print(f"Skewness: {skew_value3:.2f}")
skew_value3
sns.distplot(df['Placement_score'], kde=True, bins=10, color='skyblue')
plt.title("Skewness Visualization")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()
# Out:
# Skewness: 0.34
# /tmp/ipython-input-263257708.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Placement_score'], kde=True, bins=10, color='skyblue')

# %%
skew_value3 = skew(df['Math_score'])
print(f"Skewness: {skew_value3:.2f}")
skew_value3
sns.distplot(df['Math_score'], kde=True, bins=10, color='skyblue')
plt.title("Skewness Visualization")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()
# Out:
# Skewness: 0.56
# /tmp/ipython-input-2316704715.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Math_score'], kde=True, bins=10, color='skyblue')

# %%
skew_value3 = skew(df['Reading_score'])
print(f"Skewness: {skew_value3:.2f}")
skew_value3
sns.distplot(df['Reading_score'], kde=True, bins=10, color='skyblue')
plt.title("Skewness Visualization")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()
# Out:
# Skewness: nan
# /tmp/ipython-input-2144757700.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Reading_score'], kde=True, bins=10, color='skyblue')

# %%
skew_value3 = skew(df['Writing_score'])
print(f"Skewness: {skew_value3:.2f}")
skew_value3
sns.distplot(df['Writing_score'], kde=True, bins=10, color='skyblue')
plt.title("Skewness Visualization")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()
# Out:
# Skewness: nan
# /tmp/ipython-input-997162306.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Writing_score'], kde=True, bins=10, color='skyblue')

# %%
df_min_max_scaled
skew_value3 = skew(df_min_max_scaled['Writing_score'])
print(f"Skewness: {skew_value3:.2f}")
skew_value3
sns.distplot(df['Writing_score'], kde=True, bins=10, color='skyblue')
plt.title("Skewness Visualization")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()
# Out:
# Skewness: nan
# /tmp/ipython-input-3821866618.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Writing_score'], kde=True, bins=10, color='skyblue')
